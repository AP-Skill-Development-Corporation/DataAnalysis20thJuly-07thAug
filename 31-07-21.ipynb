# %%
import pandas as pd

# %%
birds=pd.read_csv("birds.csv")
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %% [markdown]
# ### Grouping

# %%
g_bir=birds.groupby(["type","id"])
g_bir.first()
# Out:
#            huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type id
# P    254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
#      255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
#      256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
#      257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
#      258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# ...         ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# W    176  33.20  2.11  34.31   2.25  20.36  1.57  37.95  1.42  23.67  1.26
#      177  32.31  2.16  32.74   1.98  19.05  1.40  33.37  1.14  21.20  1.00
#      178  28.51  1.80  29.35   1.78  17.60  1.21  36.04  1.14  20.81  0.83
#      179  34.12  1.90  35.57   1.93  21.22  1.39  46.24  1.27  31.39  1.05
#      180  87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34
#
# [420 rows x 10 columns]

# %%
g_birds=birds.groupby("type")

# %%
g_birds

# %%
for g_name,records in g_birds:
    print(g_name,records)
# Out:
# P       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
g_birds.mean()
# Out:
#          id        huml      humw       ulnal     ulnaw       feml      femw  \
# type
# P     272.5   34.423947  3.039211   39.177368  2.476316  28.217368  2.307895
# R     228.5   86.934400  6.065600  100.342449  4.813265  62.020000  5.266800
# SO    355.5   22.361102  2.029764   26.398095  1.743858  21.383465  1.680313
# SW     57.5  110.251121  6.423966  111.755517  5.221638  42.169655  4.275776
# T     192.0   45.699565  4.786087   45.617391  3.471739  46.277391  3.819565
# W     148.0   73.133077  4.607077   78.101385  4.102615  40.119531  3.118594
#
#            tibl      tibw       tarl      tarw
# type
# P     41.881316  2.095789  25.787368  1.902632
# R     89.877400  4.949200  59.166327  5.073878
# SO    36.326032  1.548740  25.842656  1.349375
# SW    85.317069  4.513534  45.156207  4.149914
# T     66.090870  3.451739  40.086522  3.183913
# W     76.150000  3.179231  47.543385  2.760308

# %%
g_birds.get_group("P").mean()
# Out:
# id       272.500000
# huml      34.423947
# humw       3.039211
# ulnal     39.177368
# ulnaw      2.476316
# feml      28.217368
# femw       2.307895
# tibl      41.881316
# tibw       2.095789
# tarl      25.787368
# tarw       1.902632
# dtype: float64

# %%
g_birds.get_group("SW").mean()
# Out:
# id        57.500000
# huml     110.251121
# humw       6.423966
# ulnal    111.755517
# ulnaw      5.221638
# feml      42.169655
# femw       4.275776
# tibl      85.317069
# tibw       4.513534
# tarl      45.156207
# tarw       4.149914
# dtype: float64

# %%
g_birds.get_group("SO").max()
# Out:
# id         419
# huml      48.2
# humw      4.08
# ulnal    61.94
# ulnaw     3.75
# feml     40.11
# femw      3.51
# tibl     64.97
# tibw      3.21
# tarl     48.35
# tarw      2.57
# type        SO
# dtype: object

# %% [markdown]
# ### Features
#
# * labels
# * Columns

# %%
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
birds.shape
# Out:
# (420, 12)

# %%
birds.shape[0]   #rows
# Out:
# 420

# %%
birds.shape[1]  #columns
# Out:
# 12

# %%
birds["type"]
# Out:
# 0      SW
# 1      SW
# 2      SW
# 3      SW
# 4      SW
#        ..
# 415    SO
# 416    SO
# 417    SO
# 418    SO
# 419    SO
# Name: type, Length: 420, dtype: object

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
birds["length"]=birds["type"].str.len()

# %%
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
#
#    length
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2

# %%
birds[birds.columns[1:-2]]
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 10 columns]

# %%
birds[birds.columns[1:-2]].mean(axis=1)  #default it is 0
# Out:
# 0      26.193
# 1      36.324
# 2      32.889
# 3      30.920
# 4      25.437
#         ...
# 415    11.579
# 416    12.303
# 417    12.410
# 418    13.386
# 419    11.244
# Length: 420, dtype: float64

# %%
birds["feature_mean"]=birds[birds.columns[1:-2]].mean(axis=1)

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  length  feature_mean
# 0     SW       2        26.193
# ...

# %% [markdown]
# ### Filtering

# %%
birds.count()
# Out:
# id              420
# huml            419
# humw            419
# ulnal           417
# ulnaw           418
# feml            418
# femw            419
# tibl            418
# tibw            419
# tarl            419
# tarw            419
# type            420
# length          420
# feature_mean    420
# dtype: int64

# %%
birds["tarw"].mean()
# Out:
# 2.930023866348452

# %%
birds["id"].max()
# Out:
# 419

# %%
birds["huml"].max()
# Out:
# 420.0

# %%
birds["huml"].min()
# Out:
# 9.85

# %%
birds["huml"]>90
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Name: huml, Length: 420, dtype: bool

# %%
birds[birds["huml"]>90]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# 12    12  172.00   8.44  142.00   8.43  52.18  6.68  180.00  9.62  82.58
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type  length  feature_mean
# 8    4.37   SW       2        49.514
# ...

# %%
birds[(birds["huml"]>90) & (birds["huml"]<150)]    # | = or & = and
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 13    13  148.91   6.78  121.35   6.50  44.29  6.33  155.00  6.68  73.71
# 14    14  149.19   6.98  121.48   6.21  43.33  5.39  155.00  6.61  75.65
# 15    15  140.59   6.59  115.97   5.81  39.75  5.61  166.00  7.83  74.86
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type  length  feature_mean
# 8    4.37   SW       2        49.514
# ...

# %%
birds[birds["type"]=="P"]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
birds[birds["type"]=="SO"]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 292  292  29.61  2.41  33.93   2.02  30.79  2.19  51.64  2.01  37.33  1.78
# 293  293  30.28  2.89  35.37   2.15  31.09  2.51  53.36  2.31  39.52  1.69
# 294  294  28.10  2.44  32.50   2.19  29.68  2.33  50.47  2.21  37.98  1.79
# 295  295  28.66  2.48  33.24   2.02  29.33  2.26  50.64  2.05  35.99  1.85
# 296  296  36.36  3.31  40.51   2.56  37.52  2.85  53.96  2.63  42.71  2.41
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  length  feature_mean
# 292   SO       2        19.371
# ...

# %%
birds[birds["type"]=="SO"].all(axis=1)
# Out:
# 292    True
# 293    True
# 294    True
# 295    True
# 296    True
#        ...
# 415    True
# 416    True
# 417    True
# 418    True
# 419    True
# Length: 128, dtype: bool

# %%
birds[birds["type"]=="SO"].any(axis=1)   # or gate
# Out:
# 292    True
# 293    True
# 294    True
# 295    True
# 296    True
#        ...
# 415    True
# 416    True
# 417    True
# 418    True
# 419    True
# Length: 128, dtype: bool

# %%
birds[birds["huml"]>90].all(axis=1).sum()
# Out:
# 106

# %%
birds[birds["huml"]>90].shape
# Out:
# (106, 14)

# %%
birds[birds["type"]=="SW"].all(axis=1).sum()  #AND
# Out:
# 115

# %%
birds[birds["type"]=="SW"].any(axis=1).sum()  #OR
# Out:
# 116

# %% [markdown]
# ### Sorting

# %%
birds.sort_index(axis=1,ascending=True)   #Column based - ascending order
# Out:
#      feature_mean   feml  femw   huml  humw   id  length   tarl  tarw   tibl  \
# 0          26.193  41.81  3.70  80.78  6.68    0       2  38.70  3.84   5.50
# 1          36.324  47.04  4.30  88.91  6.63    1       2  41.50  4.01  80.22
# 2          32.889  43.07  3.90  79.97  6.37    2       2  38.31  3.34  75.35
# 3          30.920  40.04  3.52  77.65  5.70    3       2  35.78  3.41  69.17
# 4          25.437  33.95  2.72  62.80  4.84    4       2  31.88  3.13  56.27
# ..            ...    ...   ...    ...   ...  ...     ...    ...   ...    ...
# 415        11.579  18.36  1.54  17.96  1.63  415       2  21.99  1.15  31.25
# 416        12.303  19.24  1.45  19.21  1.64  416       2  23.60  1.15  33.21
# 417        12.410  20.96  1.43  18.79  1.63  417       2  22.86  1.21  34.45
# 418        13.386  21.35  1.48  20.38  1.78  418       2  25.98  1.24  36.09
# 419        11.244  17.62  1.34  17.89  1.44  419       2  21.69  1.05  29.81
#
#      tibw type  ulnal  ulnaw
# ...

# %%
birds.sort_index(axis=1,ascending=False)  #Column based -descending order
# Out:
#      ulnaw  ulnal type  tibw   tibl  tarw   tarl  length   id  humw   huml  \
# 0     4.88  72.01   SW  4.03   5.50  3.84  38.70       2    0  6.68  80.78
# 1     5.59  80.53   SW  4.51  80.22  4.01  41.50       2    1  6.63  88.91
# 2     5.28  69.26   SW  4.04  75.35  3.34  38.31       2    2  6.37  79.97
# 3     4.77  65.76   SW  3.40  69.17  3.41  35.78       2    3  5.70  77.65
# 4     3.73  52.09   SW  2.96  56.27  3.13  31.88       2    4  4.84  62.80
# ..     ...    ...  ...   ...    ...   ...    ...     ...  ...   ...    ...
# 415   1.33  19.25   SO  1.33  31.25  1.15  21.99       2  415  1.63  17.96
# 416   1.49  20.76   SO  1.28  33.21  1.15  23.60       2  416  1.64  19.21
# 417   1.53  19.83   SO  1.41  34.45  1.21  22.86       2  417  1.63  18.79
# 418   1.50  22.53   SO  1.53  36.09  1.24  25.98       2  418  1.78  20.38
# 419   1.10  19.26   SO  1.24  29.81  1.05  21.69       2  419  1.44  17.89
#
#      femw   feml  feature_mean
# 0    3.70  41.81        26.193
# ...

# %%
birds.sort_index(axis=0,ascending=True)  # Row based ascending order
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  length  feature_mean
# 0     SW       2        26.193
# ...

# %%
birds.sort_index(axis=0,ascending=False)  #Row based - Descending order
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
#
#     type  length  feature_mean
# 419   SO       2        11.244
# ...

# %%
birds.sort_values(by="type",ascending=True)
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 270  270   26.92  2.73   31.54   2.01  19.10  1.59   26.68  1.35  13.21  1.23
# 269  269   27.07  2.66   31.95   1.87  18.80  1.51   26.38  1.33  12.52  1.16
# 268  268   27.57  2.67   31.60   2.12  18.92  1.52   30.42  1.58  12.46  1.46
# 267  267   18.55  2.12   21.08   1.41  18.19  1.30   25.97  1.17  11.26  1.57
# 266  266   18.46  1.79   21.12   1.47  18.83  1.21   26.33  1.05  11.41  1.56
# ..   ...     ...   ...     ...    ...    ...   ...     ...   ...    ...   ...
# 167  167   80.00  4.70  111.96   4.87  40.17  3.34   68.89  3.25  33.69  2.70
# 168  168   50.96  3.32   59.14   3.18  22.68  1.74   37.49  2.06  15.91  1.71
# 169  169   25.10  1.68   26.11   1.73  17.86  1.33   35.85  1.20  23.44  1.05
# 171  171   22.89  1.55   24.62   1.59  15.71  1.14   34.27  1.06  21.02  1.04
# 153  153  138.09  8.08  155.49   7.43  63.14  5.45  125.00  4.66  75.17  4.11
#
#     type  length  feature_mean
# ...

# %%
birds["type"]
# Out:
# 0      SW
# 1      SW
# 2      SW
# 3      SW
# 4      SW
#        ..
# 415    SO
# 416    SO
# 417    SO
# 418    SO
# 419    SO
# Name: type, Length: 420, dtype: object

# %%
birds.sort_values(by=["type","huml"],ascending=True)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl  tibw    tarl  \
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89  1.25    7.77
# 266  266   18.46   1.79   21.12   1.47   18.83  1.21   26.33  1.05   11.41
# 267  267   18.55   2.12   21.08   1.41   18.19  1.30   25.97  1.17   11.26
# 290  290   20.06   1.73   23.15   1.49   16.63  1.57   24.71  1.29   15.19
# 270  270   26.92   2.73   31.54   2.01   19.10  1.59   26.68  1.35   13.21
# ..   ...     ...    ...     ...    ...     ...   ...     ...   ...     ...
# 153  153  138.09   8.08  155.49   7.43   63.14  5.45  125.00  4.66   75.17
# 149  149  138.48   7.54  157.00   6.72   62.20  5.07  116.09  5.83   72.49
# 157  157  150.00   8.05  170.00   7.36   67.60  5.98  124.92  5.76   78.41
# 116  116  157.00   9.00  192.00   7.02   85.60  6.44  227.00  6.84  175.00
# 117  117  190.00  11.92  225.00   8.55  101.75  7.75  240.00  7.71  175.00
#
#      tarw type  length  feature_mean
# ...

# %% [markdown]
# ### Statistics
#
# * add,sub,mul,div,mod,power,mean,median,std,variance,min,max,counting etc

# %%
birds.mean()
# Out:
# id              209.500000
# huml             64.650501
# humw              4.370573
# ulnal            69.115372
# ulnaw             3.597249
# feml             36.872416
# femw              3.220883
# tibl             64.662823
# tibw              3.182339
# tarl             39.229976
# tarw              2.930024
# length            1.580952
# feature_mean     29.147160
# dtype: float64

# %%
birds["huml"].median()
# Out:
# 44.18

# %%
birds[["huml","tarw"]].sum()
# Out:
# huml    27088.56
# tarw     1227.68
# dtype: float64

# %%
birds.describe()
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw      length  \
# count  419.000000  418.000000  419.000000  419.000000  419.000000  420.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024    1.580952
# ...

# %%
birds["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
birds["type"].mode()
# Out:
# 0    SO
# dtype: object

# %%
import numpy as np

birds["huml"].agg([np.mean,np.max,np.min])
# Out:
# mean     64.650501
# amax    420.000000
# amin      9.850000
# Name: huml, dtype: float64

# %%
birds["huml"].max()
# Out:
# 420.0

# %%
birds["huml"].argmax() #huml max values index position
# Out:
# 58

# %%
birds["huml"].idxmax()
# Out:
# 58

# %%
birds["huml"].idxmin()
# Out:
# 264

# %%
birds["huml"].std()
# Out:
# 53.834548915405946

# %% [markdown]
# ### Saving

# %%
s_data=birds.describe()

# %%
s_data.to_excel("birds_description.xlsx")  # exporting final data into excel file

# %%
s_data.to_csv("bdescription.csv")

# %% [markdown]
# ### Drop

# %%
birds.drop(["huml"],axis=1)
# Out:
#       id  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# 0      0  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1      1  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2      2  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3      3  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4      4  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..   ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  415  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  416  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  417  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  418  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  419  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
#      length  feature_mean
# 0         2        26.193
# 1         2        36.324
# ...

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  length  feature_mean
# 0     SW       2        26.193
# ...

# %%
birds.drop(["type","length"],axis=1)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#      feature_mean
# 0          26.193
# 1          36.324
# ...

# %%
birds.drop(columns=["tarw","tarl"])
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw type  length  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03   SW       2
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51   SW       2
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04   SW       2
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40   SW       2
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96   SW       2
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...  ...     ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33   SO       2
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28   SO       2
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41   SO       2
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53   SO       2
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24   SO       2
#
#      feature_mean
# 0          26.193
# 1          36.324
# ...

# %%
birds.drop(birds.columns[[0,4,2]],axis=1)
# Out:
#       huml  ulnal   feml  femw   tibl  tibw   tarl  tarw type  length  \
# 0    80.78  72.01  41.81  3.70   5.50  4.03  38.70  3.84   SW       2
# 1    88.91  80.53  47.04  4.30  80.22  4.51  41.50  4.01   SW       2
# 2    79.97  69.26  43.07  3.90  75.35  4.04  38.31  3.34   SW       2
# 3    77.65  65.76  40.04  3.52  69.17  3.40  35.78  3.41   SW       2
# 4    62.80  52.09  33.95  2.72  56.27  2.96  31.88  3.13   SW       2
# ..     ...    ...    ...   ...    ...   ...    ...   ...  ...     ...
# 415  17.96  19.25  18.36  1.54  31.25  1.33  21.99  1.15   SO       2
# 416  19.21  20.76  19.24  1.45  33.21  1.28  23.60  1.15   SO       2
# 417  18.79  19.83  20.96  1.43  34.45  1.41  22.86  1.21   SO       2
# 418  20.38  22.53  21.35  1.48  36.09  1.53  25.98  1.24   SO       2
# 419  17.89  19.26  17.62  1.34  29.81  1.24  21.69  1.05   SO       2
#
#      feature_mean
# 0          26.193
# 1          36.324
# 2          32.889
# 3          30.920
# 4          25.437
# ...

# %%
# dropna() -> drops the rows where atleast 1 element is missing

df=pd.DataFrame([[1,2,3],[4,np.nan,6],[np.nan,8,np.nan]])
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  NaN  6.0
# 2  NaN  8.0  NaN

# %%
df.dropna()
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
